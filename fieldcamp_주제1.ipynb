# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.27.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4)

# %%
# !pip install pulp
# Out:
# Requirement already satisfied: pulp in /usr/local/lib/python3.10/dist-packages (2.7.0)

# %%
import numpy as np
import pandas as pd
import folium
import matplotlib.pyplot as plt
from geopy.distance import geodesic
from pulp import LpMinimize, LpProblem, LpVariable, lpSum, value

# %%
# 거리 계산 함수
def calculate_distance(x1, y1, x2, y2):
    return geodesic((y1, x1), (y2, x2)).kilometers

# 수요지와 후보지 데이터 불러오기
demand = pd.read_csv("/content/drive/MyDrive/주제1/data.csv")
candidate = pd.read_csv("/content/drive/MyDrive/주제1/target.csv")

# 이상치 제거
# 삭제할 인덱스 리스트
indexes_to_remove = [0,3,4,6,10,14,18]
candidate = candidate.drop(indexes_to_remove)
candidate = candidate.reset_index(drop=True)

# 후보지 개수 설정
num_candidates = 43

# 후보지 인구수 제한 설정
population_limit = 750

# P-Median 문제 정의
model = LpProblem("Unbalanced P-Median", sense=LpMinimize)

# 후보지 선택 변수
candidates = LpVariable.dicts('Candidate', [j for j in range(num_candidates)], lowBound=0, cat='Binary')

# 각 수요지를 각 후보지에 할당하는 이진 변수
num_demands = len(demand)
assignments = LpVariable.dicts('Assignment', [(i, j) for i in range(num_demands) for j in range(num_candidates)], lowBound=0, cat='Binary')

# 목적 함수 정의: 이동 거리 최소화
model += lpSum(demand.loc[i, '초등학령인구'] *
    calculate_distance(demand.loc[i, 'X'], demand.loc[i, 'Y'], candidate.loc[j, 'X'], candidate.loc[j, 'Y'])
    * assignments[(i, j)] for i in range(num_demands) for j in range(num_candidates))

# 제약 조건
for i in range(num_demands):
    model += lpSum(assignments[(i, j)] for j in range(num_candidates)) == 1

# 인원수 제한
for j in range(num_candidates):
    model += lpSum(assignments[(i, j)] * demand.loc[i, '초등학령인구'] for i in range(num_demands)) <= population_limit * candidates[j]

# 문제 풀기
model.solve()

results = []
for i in range(num_demands):
    demand_id = demand.loc[i, '수요지 id']
    demand_population = demand.loc[i, '초등학령인구']
    nearest_candidates = []
    for j in range(num_candidates):
        if value(assignments[(i, j)]) == 1:
            nearest_candidates.append(candidate.loc[j, '학교 id'])
    results.append((demand_id, demand_population, nearest_candidates))

# 결과 출력
print("결과:")
for result in results:
    demand_id, demand_population, nearest_candidates = result
    print(f"수요지 id {demand_id} | 초등학령인구: {demand_population} | 할당된 후보지: {nearest_candidates}")
# Out:
# /usr/local/lib/python3.10/dist-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# 결과:
# 수요지 id C1 | 초등학령인구: 1 | 할당된 후보지: ['F43']
# 수요지 id C2 | 초등학령인구: 46 | 할당된 후보지: ['F45']
# 수요지 id C3 | 초등학령인구: 36 | 할당된 후보지: ['F47']
# 수요지 id C4 | 초등학령인구: 81 | 할당된 후보지: ['F45']
# 수요지 id C5 | 초등학령인구: 25 | 할당된 후보지: ['F45']
# 수요지 id C6 | 초등학령인구: 14 | 할당된 후보지: ['F47']
# 수요지 id C7 | 초등학령인구: 14 | 할당된 후보지: ['F47']
# 수요지 id C8 | 초등학령인구: 28 | 할당된 후보지: ['F47']
# 수요지 id C9 | 초등학령인구: 21 | 할당된 후보지: ['F47']
# 수요지 id C10 | 초등학령인구: 37 | 할당된 후보지: ['F45']
# 수요지 id C11 | 초등학령인구: 28 | 할당된 후보지: ['F47']
# 수요지 id C12 | 초등학령인구: 36 | 할당된 후보지: ['F47']
# 수요지 id C13 | 초등학령인구: 29 | 할당된 후보지: ['F3']
# 수요지 id C14 | 초등학령인구: 56 | 할당된 후보지: ['F45']
# 수요지 id C15 | 초등학령인구: 30 | 할당된 후보지: ['F45']
# 수요지 id C16 | 초등학령인구: 45 | 할당된 후보지: ['F45']
# 수요지 id C17 | 초등학령인구: 30 | 할당된 후보지: ['F47']
# 수요지 id C18 | 초등학령인구: 14 | 할당된 후보지: ['F47']
# 수요지 id C19 | 초등학령인구: 37 | 할당된 후보지: ['F47']
# 수요지 id C20 | 초등학령인구: 14 | 할당된 후보지: ['F47']
# 수요지 id C21 | 초등학령인구: 14 | 할당된 후보지: ['F47']
# 수요지 id C22 | 초등학령인구: 14 | 할당된 후보지: ['F47']
# 수요지 id C23 | 초등학령인구: 40 | 할당된 후보지: ['F3']
# 수요지 id C24 | 초등학령인구: 92 | 할당된 후보지: ['F45']
# 수요지 id C25 | 초등학령인구: 112 | 할당된 후보지: ['F44']
# 수요지 id C26 | 초등학령인구: 96 | 할당된 후보지: ['F3']
# 수요지 id C27 | 초등학령인구: 104 | 할당된 후보지: ['F44']
# 수요지 id C28 | 초등학령인구: 288 | 할당된 후보지: ['F3']
# 수요지 id C29 | 초등학령인구: 248 | 할당된 후보지: ['F44']
# 수요지 id C30 | 초등학령인구: 228 | 할당된 후보지: ['F44']
# 수요지 id C31 | 초등학령인구: 4 | 할당된 후보지: ['F50']
# 수요지 id C32 | 초등학령인구: 2 | 할당된 후보지: ['F50']
# 수요지 id C33 | 초등학령인구: 362 | 할당된 후보지: ['F40']
# 수요지 id C34 | 초등학령인구: 2 | 할당된 후보지: ['F50']
# 수요지 id C35 | 초등학령인구: 41 | 할당된 후보지: ['F40']
# 수요지 id C36 | 초등학령인구: 20 | 할당된 후보지: ['F44']
# 수요지 id C37 | 초등학령인구: 1 | 할당된 후보지: ['F29']
# 수요지 id C38 | 초등학령인구: 4 | 할당된 후보지: ['F29']
# 수요지 id C39 | 초등학령인구: 334 | 할당된 후보지: ['F40']
# 수요지 id C40 | 초등학령인구: 2 | 할당된 후보지: ['F29']
# 수요지 id C41 | 초등학령인구: 2 | 할당된 후보지: ['F29']
# 수요지 id C42 | 초등학령인구: 9 | 할당된 후보지: ['F29']
# 수요지 id C43 | 초등학령인구: 2 | 할당된 후보지: ['F29']
# 수요지 id C44 | 초등학령인구: 8 | 할당된 후보지: ['F29']
# 수요지 id C45 | 초등학령인구: 6 | 할당된 후보지: ['F38']
# 수요지 id C46 | 초등학령인구: 3 | 할당된 후보지: ['F38']
# 수요지 id C47 | 초등학령인구: 5 | 할당된 후보지: ['F49']
# 수요지 id C48 | 초등학령인구: 128 | 할당된 후보지: ['F41']
# 수요지 id C49 | 초등학령인구: 2 | 할당된 후보지: ['F49']
# 수요지 id C50 | 초등학령인구: 2 | 할당된 후보지: ['F49']
# 수요지 id C51 | 초등학령인구: 2 | 할당된 후보지: ['F49']
# 수요지 id C52 | 초등학령인구: 2 | 할당된 후보지: ['F49']
# 수요지 id C53 | 초등학령인구: 2 | 할당된 후보지: ['F49']
# 수요지 id C54 | 초등학령인구: 1 | 할당된 후보지: ['F48']
# 수요지 id C55 | 초등학령인구: 7 | 할당된 후보지: ['F37']
# 수요지 id C56 | 초등학령인구: 1 | 할당된 후보지: ['F37']
# 수요지 id C57 | 초등학령인구: 5 | 할당된 후보지: ['F37']
# 수요지 id C58 | 초등학령인구: 2 | 할당된 후보지: ['F37']
# 수요지 id C59 | 초등학령인구: 3 | 할당된 후보지: ['F37']
# 수요지 id C60 | 초등학령인구: 8 | 할당된 후보지: ['F37']
# 수요지 id C61 | 초등학령인구: 2 | 할당된 후보지: ['F49']
# 수요지 id C62 | 초등학령인구: 2 | 할당된 후보지: ['F42']
# 수요지 id C63 | 초등학령인구: 3 | 할당된 후보지: ['F37']
# 수요지 id C64 | 초등학령인구: 3 | 할당된 후보지: ['F37']
# 수요지 id C65 | 초등학령인구: 2 | 할당된 후보지: ['F37']
# 수요지 id C66 | 초등학령인구: 2 | 할당된 후보지: ['F37']
# 수요지 id C67 | 초등학령인구: 2 | 할당된 후보지: ['F37']
# 수요지 id C68 | 초등학령인구: 124 | 할당된 후보지: ['F48']
# 수요지 id C69 | 초등학령인구: 400 | 할당된 후보지: ['F48']
# 수요지 id C70 | 초등학령인구: 2 | 할당된 후보지: ['F37']
# 수요지 id C71 | 초등학령인구: 2 | 할당된 후보지: ['F37']
# 수요지 id C72 | 초등학령인구: 2 | 할당된 후보지: ['F37']
# 수요지 id C73 | 초등학령인구: 4 | 할당된 후보지: ['F37']
# 수요지 id C74 | 초등학령인구: 2 | 할당된 후보지: ['F33']
# 수요지 id C75 | 초등학령인구: 98 | 할당된 후보지: ['F48']
# 수요지 id C76 | 초등학령인구: 188 | 할당된 후보지: ['F37']
# 수요지 id C77 | 초등학령인구: 52 | 할당된 후보지: ['F48']
# 수요지 id C78 | 초등학령인구: 161 | 할당된 후보지: ['F35']
# 수요지 id C79 | 초등학령인구: 163 | 할당된 후보지: ['F35']
# 수요지 id C80 | 초등학령인구: 2 | 할당된 후보지: ['F33']
# 수요지 id C81 | 초등학령인구: 2 | 할당된 후보지: ['F33']
# 수요지 id C82 | 초등학령인구: 125 | 할당된 후보지: ['F35']
# 수요지 id C83 | 초등학령인구: 210 | 할당된 후보지: ['F33']
# 수요지 id C84 | 초등학령인구: 258 | 할당된 후보지: ['F35']
# 수요지 id C85 | 초등학령인구: 73 | 할당된 후보지: ['F2']
# 수요지 id C86 | 초등학령인구: 164 | 할당된 후보지: ['F33']
# 수요지 id C87 | 초등학령인구: 171 | 할당된 후보지: ['F33']
# 수요지 id C88 | 초등학령인구: 140 | 할당된 후보지: ['F34']
# 수요지 id C89 | 초등학령인구: 204 | 할당된 후보지: ['F2']
# 수요지 id C90 | 초등학령인구: 190 | 할당된 후보지: ['F2']
# 수요지 id C91 | 초등학령인구: 134 | 할당된 후보지: ['F2']
# 수요지 id C92 | 초등학령인구: 114 | 할당된 후보지: ['F34']
# 수요지 id C93 | 초등학령인구: 112 | 할당된 후보지: ['F2']
# 수요지 id C94 | 초등학령인구: 1 | 할당된 후보지: ['F25']
# 수요지 id C95 | 초등학령인구: 1 | 할당된 후보지: ['F25']
# 수요지 id C96 | 초등학령인구: 2 | 할당된 후보지: ['F25']
# 수요지 id C97 | 초등학령인구: 3 | 할당된 후보지: ['F25']
# 수요지 id C98 | 초등학령인구: 1 | 할당된 후보지: ['F25']
# 수요지 id C99 | 초등학령인구: 2 | 할당된 후보지: ['F25']
# 수요지 id C100 | 초등학령인구: 6 | 할당된 후보지: ['F23']
# 수요지 id C101 | 초등학령인구: 6 | 할당된 후보지: ['F23']
# 수요지 id C102 | 초등학령인구: 251 | 할당된 후보지: ['F23']
# 수요지 id C103 | 초등학령인구: 18 | 할당된 후보지: ['F9']
# 수요지 id C104 | 초등학령인구: 5 | 할당된 후보지: ['F9']
# 수요지 id C105 | 초등학령인구: 13 | 할당된 후보지: ['F12']
# 수요지 id C106 | 초등학령인구: 9 | 할당된 후보지: ['F22']
# 수요지 id C107 | 초등학령인구: 3 | 할당된 후보지: ['F9']
# 수요지 id C108 | 초등학령인구: 9 | 할당된 후보지: ['F9']
# 수요지 id C109 | 초등학령인구: 10 | 할당된 후보지: ['F12']
# 수요지 id C110 | 초등학령인구: 4 | 할당된 후보지: ['F9']
# 수요지 id C111 | 초등학령인구: 4 | 할당된 후보지: ['F9']
# 수요지 id C112 | 초등학령인구: 1 | 할당된 후보지: ['F12']
# 수요지 id C113 | 초등학령인구: 3 | 할당된 후보지: ['F12']
# 수요지 id C114 | 초등학령인구: 18 | 할당된 후보지: ['F12']
# 수요지 id C115 | 초등학령인구: 16 | 할당된 후보지: ['F22']
# 수요지 id C116 | 초등학령인구: 87 | 할당된 후보지: ['F28']
# 수요지 id C117 | 초등학령인구: 2 | 할당된 후보지: ['F9']
# 수요지 id C118 | 초등학령인구: 1 | 할당된 후보지: ['F9']
# 수요지 id C119 | 초등학령인구: 1 | 할당된 후보지: ['F12']
# 수요지 id C120 | 초등학령인구: 1 | 할당된 후보지: ['F12']
# 수요지 id C121 | 초등학령인구: 2 | 할당된 후보지: ['F22']
# 수요지 id C122 | 초등학령인구: 3 | 할당된 후보지: ['F22']
# 수요지 id C123 | 초등학령인구: 3 | 할당된 후보지: ['F22']
# 수요지 id C124 | 초등학령인구: 1 | 할당된 후보지: ['F12']
# 수요지 id C125 | 초등학령인구: 1 | 할당된 후보지: ['F12']
# 수요지 id C126 | 초등학령인구: 1 | 할당된 후보지: ['F12']
# 수요지 id C127 | 초등학령인구: 3 | 할당된 후보지: ['F22']
# 수요지 id C128 | 초등학령인구: 159 | 할당된 후보지: ['F22']
# 수요지 id C129 | 초등학령인구: 3 | 할당된 후보지: ['F9']
# 수요지 id C130 | 초등학령인구: 45 | 할당된 후보지: ['F12']
# 수요지 id C131 | 초등학령인구: 6 | 할당된 후보지: ['F22']
# 수요지 id C132 | 초등학령인구: 1 | 할당된 후보지: ['F22']
# 수요지 id C133 | 초등학령인구: 1 | 할당된 후보지: ['F22']
# 수요지 id C134 | 초등학령인구: 10 | 할당된 후보지: ['F22']
# 수요지 id C135 | 초등학령인구: 9 | 할당된 후보지: ['F12']
# 수요지 id C136 | 초등학령인구: 9 | 할당된 후보지: ['F22']
# 수요지 id C137 | 초등학령인구: 3 | 할당된 후보지: ['F22']
# 수요지 id C138 | 초등학령인구: 64 | 할당된 후보지: ['F28']
# 수요지 id C139 | 초등학령인구: 6 | 할당된 후보지: ['F9']
# 수요지 id C140 | 초등학령인구: 21 | 할당된 후보지: ['F12']
# 수요지 id C141 | 초등학령인구: 25 | 할당된 후보지: ['F22']
# 수요지 id C142 | 초등학령인구: 4 | 할당된 후보지: ['F22']
# 수요지 id C143 | 초등학령인구: 12 | 할당된 후보지: ['F22']
# 수요지 id C144 | 초등학령인구: 1 | 할당된 후보지: ['F9']
# 수요지 id C145 | 초등학령인구: 3 | 할당된 후보지: ['F9']
# 수요지 id C146 | 초등학령인구: 2 | 할당된 후보지: ['F12']
# 수요지 id C147 | 초등학령인구: 2 | 할당된 후보지: ['F12']
# 수요지 id C148 | 초등학령인구: 17 | 할당된 후보지: ['F12']
# 수요지 id C149 | 초등학령인구: 10 | 할당된 후보지: ['F12']
# 수요지 id C150 | 초등학령인구: 1 | 할당된 후보지: ['F22']
# 수요지 id C151 | 초등학령인구: 2 | 할당된 후보지: ['F22']
# 수요지 id C152 | 초등학령인구: 6 | 할당된 후보지: ['F22']
# 수요지 id C153 | 초등학령인구: 14 | 할당된 후보지: ['F16']
# 수요지 id C154 | 초등학령인구: 5 | 할당된 후보지: ['F12']
# 수요지 id C155 | 초등학령인구: 10 | 할당된 후보지: ['F12']
# 수요지 id C156 | 초등학령인구: 4 | 할당된 후보지: ['F12']
# 수요지 id C157 | 초등학령인구: 12 | 할당된 후보지: ['F12']
# 수요지 id C158 | 초등학령인구: 11 | 할당된 후보지: ['F22']
# 수요지 id C159 | 초등학령인구: 7 | 할당된 후보지: ['F22']
# 수요지 id C160 | 초등학령인구: 11 | 할당된 후보지: ['F22']
# 수요지 id C161 | 초등학령인구: 1 | 할당된 후보지: ['F16']
# 수요지 id C162 | 초등학령인구: 3 | 할당된 후보지: ['F16']
# 수요지 id C163 | 초등학령인구: 5 | 할당된 후보지: ['F16']
# 수요지 id C164 | 초등학령인구: 2 | 할당된 후보지: ['F16']
# 수요지 id C165 | 초등학령인구: 1 | 할당된 후보지: ['F12']
# 수요지 id C166 | 초등학령인구: 4 | 할당된 후보지: ['F12']
# 수요지 id C167 | 초등학령인구: 24 | 할당된 후보지: ['F12']
# 수요지 id C168 | 초등학령인구: 4 | 할당된 후보지: ['F18']
# 수요지 id C169 | 초등학령인구: 46 | 할당된 후보지: ['F18']
# 수요지 id C170 | 초등학령인구: 22 | 할당된 후보지: ['F24']
# 수요지 id C171 | 초등학령인구: 4 | 할당된 후보지: ['F16']
# 수요지 id C172 | 초등학령인구: 2 | 할당된 후보지: ['F16']
# 수요지 id C173 | 초등학령인구: 10 | 할당된 후보지: ['F18']
# 수요지 id C174 | 초등학령인구: 6 | 할당된 후보지: ['F18']
# 수요지 id C175 | 초등학령인구: 3 | 할당된 후보지: ['F18']
# 수요지 id C176 | 초등학령인구: 3 | 할당된 후보지: ['F18']
# 수요지 id C177 | 초등학령인구: 45 | 할당된 후보지: ['F24']
# 수요지 id C178 | 초등학령인구: 34 | 할당된 후보지: ['F16']
# 수요지 id C179 | 초등학령인구: 9 | 할당된 후보지: ['F16']
# 수요지 id C180 | 초등학령인구: 20 | 할당된 후보지: ['F16']
# 수요지 id C181 | 초등학령인구: 22 | 할당된 후보지: ['F16']
# 수요지 id C182 | 초등학령인구: 5 | 할당된 후보지: ['F16']
# 수요지 id C183 | 초등학령인구: 24 | 할당된 후보지: ['F18']
# 수요지 id C184 | 초등학령인구: 2 | 할당된 후보지: ['F18']
# 수요지 id C185 | 초등학령인구: 1 | 할당된 후보지: ['F18']
# 수요지 id C186 | 초등학령인구: 5 | 할당된 후보지: ['F18']
# 수요지 id C187 | 초등학령인구: 4 | 할당된 후보지: ['F24']
# 수요지 id C188 | 초등학령인구: 5 | 할당된 후보지: ['F24']
# 수요지 id C189 | 초등학령인구: 9 | 할당된 후보지: ['F24']
# 수요지 id C190 | 초등학령인구: 6 | 할당된 후보지: ['F24']
# 수요지 id C191 | 초등학령인구: 38 | 할당된 후보지: ['F16']
# 수요지 id C192 | 초등학령인구: 6 | 할당된 후보지: ['F16']
# 수요지 id C193 | 초등학령인구: 3 | 할당된 후보지: ['F16']
# 수요지 id C194 | 초등학령인구: 1 | 할당된 후보지: ['F16']
# 수요지 id C195 | 초등학령인구: 2 | 할당된 후보지: ['F18']
# 수요지 id C196 | 초등학령인구: 1 | 할당된 후보지: ['F24']
# 수요지 id C197 | 초등학령인구: 4 | 할당된 후보지: ['F24']
# 수요지 id C198 | 초등학령인구: 13 | 할당된 후보지: ['F24']
# 수요지 id C199 | 초등학령인구: 2 | 할당된 후보지: ['F24']
# 수요지 id C200 | 초등학령인구: 2 | 할당된 후보지: ['F24']
# 수요지 id C201 | 초등학령인구: 37 | 할당된 후보지: ['F14']
# 수요지 id C202 | 초등학령인구: 2 | 할당된 후보지: ['F16']
# 수요지 id C203 | 초등학령인구: 2 | 할당된 후보지: ['F16']
# 수요지 id C204 | 초등학령인구: 4 | 할당된 후보지: ['F16']
# 수요지 id C205 | 초등학령인구: 4 | 할당된 후보지: ['F16']
# 수요지 id C206 | 초등학령인구: 7 | 할당된 후보지: ['F18']
# 수요지 id C207 | 초등학령인구: 4 | 할당된 후보지: ['F18']
# 수요지 id C208 | 초등학령인구: 17 | 할당된 후보지: ['F24']
# 수요지 id C209 | 초등학령인구: 54 | 할당된 후보지: ['F20']
# 수요지 id C210 | 초등학령인구: 12 | 할당된 후보지: ['F20']
# 수요지 id C211 | 초등학령인구: 1 | 할당된 후보지: ['F16']
# 수요지 id C212 | 초등학령인구: 7 | 할당된 후보지: ['F16']
# 수요지 id C213 | 초등학령인구: 16 | 할당된 후보지: ['F16']
# 수요지 id C214 | 초등학령인구: 2 | 할당된 후보지: ['F16']
# 수요지 id C215 | 초등학령인구: 2 | 할당된 후보지: ['F16']
# 수요지 id C216 | 초등학령인구: 37 | 할당된 후보지: ['F18']
# 수요지 id C217 | 초등학령인구: 4 | 할당된 후보지: ['F18']
# 수요지 id C218 | 초등학령인구: 2 | 할당된 후보지: ['F24']
# 수요지 id C219 | 초등학령인구: 166 | 할당된 후보지: ['F6']
# 수요지 id C220 | 초등학령인구: 51 | 할당된 후보지: ['F20']
# 수요지 id C221 | 초등학령인구: 3 | 할당된 후보지: ['F20']
# 수요지 id C222 | 초등학령인구: 1 | 할당된 후보지: ['F20']
# 수요지 id C223 | 초등학령인구: 33 | 할당된 후보지: ['F16']
# 수요지 id C224 | 초등학령인구: 10 | 할당된 후보지: ['F16']
# 수요지 id C225 | 초등학령인구: 25 | 할당된 후보지: ['F16']
# 수요지 id C226 | 초등학령인구: 4 | 할당된 후보지: ['F16']
# 수요지 id C227 | 초등학령인구: 2 | 할당된 후보지: ['F18']
# 수요지 id C228 | 초등학령인구: 1 | 할당된 후보지: ['F18']
# 수요지 id C229 | 초등학령인구: 1 | 할당된 후보지: ['F18']
# 수요지 id C230 | 초등학령인구: 70 | 할당된 후보지: ['F24']
# 수요지 id C231 | 초등학령인구: 18 | 할당된 후보지: ['F14']
# 수요지 id C232 | 초등학령인구: 2 | 할당된 후보지: ['F20']
# 수요지 id C233 | 초등학령인구: 40 | 할당된 후보지: ['F20']
# 수요지 id C234 | 초등학령인구: 27 | 할당된 후보지: ['F21']
# 수요지 id C235 | 초등학령인구: 9 | 할당된 후보지: ['F21']
# 수요지 id C236 | 초등학령인구: 2 | 할당된 후보지: ['F21']
# 수요지 id C237 | 초등학령인구: 55 | 할당된 후보지: ['F18']
# 수요지 id C238 | 초등학령인구: 18 | 할당된 후보지: ['F20']
# 수요지 id C239 | 초등학령인구: 5 | 할당된 후보지: ['F20']
# 수요지 id C240 | 초등학령인구: 16 | 할당된 후보지: ['F20']
# 수요지 id C241 | 초등학령인구: 16 | 할당된 후보지: ['F21']
# 수요지 id C242 | 초등학령인구: 48 | 할당된 후보지: ['F18']
# 수요지 id C243 | 초등학령인구: 142 | 할당된 후보지: ['F24']
# 수요지 id C244 | 초등학령인구: 1 | 할당된 후보지: ['F20']
# 수요지 id C245 | 초등학령인구: 27 | 할당된 후보지: ['F20']
# 수요지 id C246 | 초등학령인구: 6 | 할당된 후보지: ['F20']
# 수요지 id C247 | 초등학령인구: 4 | 할당된 후보지: ['F20']
# 수요지 id C248 | 초등학령인구: 10 | 할당된 후보지: ['F20']
# 수요지 id C249 | 초등학령인구: 2 | 할당된 후보지: ['F20']
# 수요지 id C250 | 초등학령인구: 320 | 할당된 후보지: ['F8']
# 수요지 id C251 | 초등학령인구: 339 | 할당된 후보지: ['F18']
# 수요지 id C252 | 초등학령인구: 44 | 할당된 후보지: ['F18']
# 수요지 id C253 | 초등학령인구: 29 | 할당된 후보지: ['F20']
# 수요지 id C254 | 초등학령인구: 23 | 할당된 후보지: ['F20']
# 수요지 id C255 | 초등학령인구: 14 | 할당된 후보지: ['F20']
# 수요지 id C256 | 초등학령인구: 8 | 할당된 후보지: ['F20']
# 수요지 id C257 | 초등학령인구: 14 | 할당된 후보지: ['F20']
# 수요지 id C258 | 초등학령인구: 1 | 할당된 후보지: ['F21']
# 수요지 id C259 | 초등학령인구: 6 | 할당된 후보지: ['F20']
# 수요지 id C260 | 초등학령인구: 11 | 할당된 후보지: ['F20']
# 수요지 id C261 | 초등학령인구: 26 | 할당된 후보지: ['F20']
# 수요지 id C262 | 초등학령인구: 1 | 할당된 후보지: ['F8']
# 수요지 id C263 | 초등학령인구: 6 | 할당된 후보지: ['F20']
# 수요지 id C264 | 초등학령인구: 6 | 할당된 후보지: ['F20']
# 수요지 id C265 | 초등학령인구: 5 | 할당된 후보지: ['F20']
# 수요지 id C266 | 초등학령인구: 6 | 할당된 후보지: ['F21']
# 수요지 id C267 | 초등학령인구: 14 | 할당된 후보지: ['F8']
# 수요지 id C268 | 초등학령인구: 6 | 할당된 후보지: ['F20']
# 수요지 id C269 | 초등학령인구: 1 | 할당된 후보지: ['F21']
# 수요지 id C270 | 초등학령인구: 2 | 할당된 후보지: ['F21']
# 수요지 id C271 | 초등학령인구: 2 | 할당된 후보지: ['F21']
# 수요지 id C272 | 초등학령인구: 3 | 할당된 후보지: ['F21']
# 수요지 id C273 | 초등학령인구: 3 | 할당된 후보지: ['F21']
# 수요지 id C274 | 초등학령인구: 33 | 할당된 후보지: ['F8']
# 수요지 id C275 | 초등학령인구: 4 | 할당된 후보지: ['F8']
# 수요지 id C276 | 초등학령인구: 62 | 할당된 후보지: ['F8']
# 수요지 id C277 | 초등학령인구: 2 | 할당된 후보지: ['F21']
# 수요지 id C278 | 초등학령인구: 2 | 할당된 후보지: ['F21']
# 수요지 id C279 | 초등학령인구: 1 | 할당된 후보지: ['F8']
# 수요지 id C280 | 초등학령인구: 2 | 할당된 후보지: ['F8']
# 수요지 id C281 | 초등학령인구: 2 | 할당된 후보지: ['F8']
# 수요지 id C282 | 초등학령인구: 50 | 할당된 후보지: ['F8']
# 수요지 id C283 | 초등학령인구: 2 | 할당된 후보지: ['F21']
# 수요지 id C284 | 초등학령인구: 1 | 할당된 후보지: ['F21']
# 수요지 id C285 | 초등학령인구: 1 | 할당된 후보지: ['F8']
# 수요지 id C286 | 초등학령인구: 4 | 할당된 후보지: ['F8']
# 수요지 id C287 | 초등학령인구: 11 | 할당된 후보지: ['F31']
# 수요지 id C288 | 초등학령인구: 72 | 할당된 후보지: ['F10']
# 수요지 id C289 | 초등학령인구: 4 | 할당된 후보지: ['F30']
# 수요지 id C290 | 초등학령인구: 4 | 할당된 후보지: ['F30']
# 수요지 id C291 | 초등학령인구: 1 | 할당된 후보지: ['F30']
# 수요지 id C292 | 초등학령인구: 2 | 할당된 후보지: ['F31']
# 수요지 id C293 | 초등학령인구: 39 | 할당된 후보지: ['F31']
# 수요지 id C294 | 초등학령인구: 1 | 할당된 후보지: ['F31']
# 수요지 id C295 | 초등학령인구: 169 | 할당된 후보지: ['F10']
# 수요지 id C296 | 초등학령인구: 4 | 할당된 후보지: ['F10']
# 수요지 id C297 | 초등학령인구: 29 | 할당된 후보지: ['F30']
# 수요지 id C298 | 초등학령인구: 1 | 할당된 후보지: ['F30']
# 수요지 id C299 | 초등학령인구: 28 | 할당된 후보지: ['F10']
# 수요지 id C300 | 초등학령인구: 6 | 할당된 후보지: ['F30']
# 수요지 id C301 | 초등학령인구: 108 | 할당된 후보지: ['F30']
# 수요지 id C302 | 초등학령인구: 12 | 할당된 후보지: ['F10']
# 수요지 id C303 | 초등학령인구: 115 | 할당된 후보지: ['F31']
# 수요지 id C304 | 초등학령인구: 31 | 할당된 후보지: ['F31']
# 수요지 id C305 | 초등학령인구: 126 | 할당된 후보지: ['F10']
# 수요지 id C306 | 초등학령인구: 2 | 할당된 후보지: ['F10']
# 수요지 id C307 | 초등학령인구: 2 | 할당된 후보지: ['F10']
# 수요지 id C308 | 초등학령인구: 12 | 할당된 후보지: ['F30']
# 수요지 id C309 | 초등학령인구: 1 | 할당된 후보지: ['F10']
# 수요지 id C310 | 초등학령인구: 1 | 할당된 후보지: ['F10']
# 수요지 id C311 | 초등학령인구: 11 | 할당된 후보지: ['F10']

# %%
candidate_assignments = {j: [] for j in range(num_candidates)}

for i in range(num_demands):
    demand_id = demand.loc[i, '수요지 id']
    demand_population = demand.loc[i, '초등학령인구']
    nearest_candidates = []
    for j in range(num_candidates):
        if value(assignments[(i, j)]) == 1:
            nearest_candidates.append(candidate.loc[j, '학교 id'])
            candidate_assignments[j].append(demand_id)
    results.append((demand_id, demand_population, nearest_candidates))

print("결과:")
for j in range(num_candidates):
    candidate_id = candidate.loc[j, '학교 id']
    assigned_demand_count = len(candidate_assignments[j])
    assigned_population = sum(demand.loc[demand['수요지 id'].isin(candidate_assignments[j]), '초등학령인구'])
    print(f"후보지 id {candidate_id} | 할당된 수요지 개수: {assigned_demand_count} | 할당된 인구: {assigned_population}")
# Out:
# 결과:
# 후보지 id F2 | 할당된 수요지 개수: 5 | 할당된 인구: 713
# 후보지 id F3 | 할당된 수요지 개수: 4 | 할당된 인구: 453
# 후보지 id F6 | 할당된 수요지 개수: 1 | 할당된 인구: 166
# 후보지 id F8 | 할당된 수요지 개수: 12 | 할당된 인구: 494
# 후보지 id F9 | 할당된 수요지 개수: 12 | 할당된 인구: 59
# 후보지 id F10 | 할당된 수요지 개수: 11 | 할당된 인구: 428
# 후보지 id F12 | 할당된 수요지 개수: 24 | 할당된 인구: 216
# 후보지 id F13 | 할당된 수요지 개수: 0 | 할당된 인구: 0
# 후보지 id F14 | 할당된 수요지 개수: 2 | 할당된 인구: 55
# 후보지 id F16 | 할당된 수요지 개수: 29 | 할당된 인구: 281
# 후보지 id F17 | 할당된 수요지 개수: 0 | 할당된 인구: 0
# 후보지 id F18 | 할당된 수요지 개수: 22 | 할당된 인구: 648
# 후보지 id F20 | 할당된 수요지 개수: 28 | 할당된 인구: 406
# 후보지 id F21 | 할당된 수요지 개수: 15 | 할당된 인구: 79
# 후보지 id F22 | 할당된 수요지 개수: 22 | 할당된 인구: 304
# 후보지 id F23 | 할당된 수요지 개수: 3 | 할당된 인구: 263
# 후보지 id F24 | 할당된 수요지 개수: 15 | 할당된 인구: 344
# 후보지 id F25 | 할당된 수요지 개수: 6 | 할당된 인구: 10
# 후보지 id F26 | 할당된 수요지 개수: 0 | 할당된 인구: 0
# 후보지 id F27 | 할당된 수요지 개수: 0 | 할당된 인구: 0
# 후보지 id F28 | 할당된 수요지 개수: 2 | 할당된 인구: 151
# 후보지 id F29 | 할당된 수요지 개수: 7 | 할당된 인구: 28
# 후보지 id F30 | 할당된 수요지 개수: 8 | 할당된 인구: 165
# 후보지 id F31 | 할당된 수요지 개수: 6 | 할당된 인구: 199
# 후보지 id F32 | 할당된 수요지 개수: 0 | 할당된 인구: 0
# 후보지 id F33 | 할당된 수요지 개수: 6 | 할당된 인구: 551
# 후보지 id F34 | 할당된 수요지 개수: 2 | 할당된 인구: 254
# 후보지 id F35 | 할당된 수요지 개수: 4 | 할당된 인구: 707
# 후보지 id F36 | 할당된 수요지 개수: 0 | 할당된 인구: 0
# 후보지 id F37 | 할당된 수요지 개수: 16 | 할당된 인구: 236
# 후보지 id F38 | 할당된 수요지 개수: 2 | 할당된 인구: 9
# 후보지 id F39 | 할당된 수요지 개수: 0 | 할당된 인구: 0
# 후보지 id F40 | 할당된 수요지 개수: 3 | 할당된 인구: 737
# 후보지 id F41 | 할당된 수요지 개수: 1 | 할당된 인구: 128
# 후보지 id F42 | 할당된 수요지 개수: 1 | 할당된 인구: 2
# 후보지 id F43 | 할당된 수요지 개수: 1 | 할당된 인구: 1
# 후보지 id F44 | 할당된 수요지 개수: 5 | 할당된 인구: 712
# 후보지 id F45 | 할당된 수요지 개수: 8 | 할당된 인구: 412
# 후보지 id F46 | 할당된 수요지 개수: 0 | 할당된 인구: 0
# 후보지 id F47 | 할당된 수요지 개수: 13 | 할당된 인구: 300
# 후보지 id F48 | 할당된 수요지 개수: 5 | 할당된 인구: 675
# 후보지 id F49 | 할당된 수요지 개수: 7 | 할당된 인구: 17
# 후보지 id F50 | 할당된 수요지 개수: 3 | 할당된 인구: 8

# %%
distance_exceeded_results = []

# 결과 저장 및 거리 초과 여부 확인
for i in range(num_demands):
    demand_id = demand.loc[i, '수요지 id']
    demand_population = demand.loc[i, '초등학령인구']
    nearest_candidates = []
    for j in range(num_candidates):
        if value(assignments[(i, j)]) == 1:
            demand_coords = (demand.loc[i, 'X'], demand.loc[i, 'Y'])
            candidate_coords = (candidate.loc[j, 'X'], candidate.loc[j, 'Y'])
            distance = calculate_distance(demand_coords[0], demand_coords[1], candidate_coords[0], candidate_coords[1])
            if distance <= 1.0:
                nearest_candidates.append(candidate.loc[j, '학교 id'])
            else:
                distance_exceeded_results.append((demand_id, demand_population, candidate.loc[j, '학교 id'], distance))
    results.append((demand_id, demand_population, nearest_candidates))

# 거리 초과 결과 출력
print("거리 초과 결과:")
for result in distance_exceeded_results:
    demand_id, demand_population, nearest_candidate, distance = result
    print(f"수요지 id {demand_id} | 초등학령인구: {demand_population} | 할당된 후보지: {nearest_candidate} | 거리: {distance:.2f} km")
# Out:
# 거리 초과 결과:
# 수요지 id C61 | 초등학령인구: 2 | 할당된 후보지: F49 | 거리: 1.01 km
# 수요지 id C69 | 초등학령인구: 400 | 할당된 후보지: F48 | 거리: 1.03 km
# 수요지 id C76 | 초등학령인구: 188 | 할당된 후보지: F37 | 거리: 1.17 km
# 수요지 id C77 | 초등학령인구: 52 | 할당된 후보지: F48 | 거리: 1.04 km
# 수요지 id C83 | 초등학령인구: 210 | 할당된 후보지: F33 | 거리: 1.10 km
# 수요지 id C85 | 초등학령인구: 73 | 할당된 후보지: F2 | 거리: 1.52 km
# 수요지 id C86 | 초등학령인구: 164 | 할당된 후보지: F33 | 거리: 1.14 km
# 수요지 id C87 | 초등학령인구: 171 | 할당된 후보지: F33 | 거리: 1.34 km

# %%
import folium

# 수요지와 후보지 위치 정보 추출
demand_locations = demand[['수요지 id', 'Y', 'X']]
candidate_locations = candidate[['학교 id', 'Y', 'X']]

# 지도 초기화
m = folium.Map(location=[demand_locations['Y'].mean(), demand_locations['X'].mean()], zoom_start=12)

# 수요지 위치 마커 추가
for idx, row in demand_locations.iterrows():
    folium.Marker([row['Y'], row['X']], icon=folium.Icon(color='blue'), tooltip=f"Demand {row['수요지 id']}").add_to(m)

# 후보지 위치 마커 추가
for idx, row in candidate_locations.iterrows():
    folium.Marker([row['Y'], row['X']], icon=folium.Icon(color='green'), tooltip=f"Candidate {row['학교 id']}").add_to(m)

# 선택된 후보지와 수요지 간의 선 그리기 및 거리 표시
for i in range(num_demands):
    for j in range(num_candidates):
        if value(assignments[(i, j)]) == 1:
            demand_coords = (demand_locations.loc[i, 'Y'], demand_locations.loc[i, 'X'])
            candidate_coords = (candidate_locations.loc[j, 'Y'], candidate_locations.loc[j, 'X'])
            distance = calculate_distance(demand_coords[1], demand_coords[0], candidate_coords[1], candidate_coords[0])
            assigned_population = demand.loc[i, '초등학령인구']

            folium.PolyLine([demand_coords, candidate_coords], color="red", weight=2.5, opacity=1).add_to(m)

            tooltip_content = f"Demand ID: {demand.loc[i, '수요지 id']}<br>Distance: {distance:.2f} km<br>Assigned Population: {assigned_population}"
            folium.Marker(demand_coords, icon=folium.Icon(color='blue'), tooltip=folium.Tooltip(tooltip_content)).add_to(m)
# 지도 저장
m.save("result_map.html")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_617538451381326915a02a2302f4f2ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_617538451381326915a02a2302f4f2ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_617538451381326915a02a2302f4f2ce = L.map(
#                 &quot;map_617538451381326915a02a2302f4f2ce&quot;,
#                 {
#                     center: [37.48130973118971, 126.59871058778138],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3e60dd813af7616c7f758eebd83da43 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_617538451381326915a02a2302f4f2ce);
#
#
#             var marker_fa6e545e4345d79a526072f9cfbfb031 = L.marker(
#                 [37.4637824, 126.3715048],
#                 {}
#             ).addTo(map_617538451381326915a02a2302f4f2ce);
#
#
#             var icon_f62626d58ae1e19303fa00f212b5c16b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fa6e545e4345d79a526072f9cfbfb031.setIcon(icon_f62626d58ae1e19303fa00f212b5c16b);
#
#
#             marker_fa6e545e4345d79a526072f9cfbfb031.bindTooltip(
#                 `&lt;div&gt;
#                      Demand C1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f5e248481d198ddf4449dc9e15b40cd0 = L.marker(
#                 [37.4957824, 126.4795048],
#                 {}
#             ).addTo(map_617538451381326915a02a2302f4f2ce);
#
#
#             var icon_d4a67bb359398c36e071843fb1a23cca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f5e248481d198ddf4449dc9e15b40cd0.setIcon(icon_d4a67bb359398c36e071843fb1a23cca);
#
#
#             marker_f5e248481d198ddf4449dc9e15b40cd0.bindTooltip(
#                 `&lt;div&gt;
#                      Demand C2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5927e9cfcbd2abb6df1913d304e200b1 = L.marker(
#                 [37.4997824, 126.4815048],
#                 {}
#             ).addTo(map_617538451381326915a02a2302f4f2ce);
#
#
#             var icon_59cd2c65dae03ec974848f8ee258d0e3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5927e9cfcbd2abb6df1913d304e200b1.setIcon(icon_59cd2c65dae03ec974848f8ee258d0e3);
#
#
#             marker_5927e9cfcbd2abb6df1913d304e200b1.bindTooltip(
#                 `&lt;div&gt;
#                      Demand C3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f298d855640183d12439ce27bf65bdf2 = L.marker(
#                 [37.4957824, 126.4825048],
#                 {}
#             ).addTo(map_617538451381326915a02a2302f4f2ce);
#
#
#             var icon_ba20e6cdb1f79f0175dc08c955b4bda3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f298d855640183d12439ce27bf65bdf2.setIcon(icon_ba20e6cdb1f79f0175dc08c955b4bda3);
#
#
#             marker_f298d855640183d12439ce27bf65bdf2.bindTooltip(
#                 `&lt;div&gt;
#                      Demand C4
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b58562067fa1658a8ac0d64d9c91d4da = L.marker(
#                 [37.4977824, 126.4835048],
#                 {}
#             ).addTo(map_617538451381326915a02a2302f4f2ce);
#
#
#             var icon_59558829e9ec07279e98a91431a2df48 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b58562

# %%
result_list = []

for i in range(num_demands):
    demand_id = demand.loc[i, '수요지 id']
    demand_population = demand.loc[i, '초등학령인구']

    # 모든 후보지에 대한 정보를 리스트에 추가
    for j in range(num_candidates):
        school_id = candidate.loc[j, '학교 id']
        is_assigned = value(assignments[(i, j)]) == 1
        if is_assigned:
            nearest_candidates.append(school_id)
        result_list.append({'수요지 id': demand_id, '학교 id': school_id, '할당 학령인구': demand_population if is_assigned else 0})

# 결과를 저장할 데이터프레임 생성
output_df = pd.DataFrame(result_list)

# 저장된 결과를 출력
print("저장된 결과:")
print(output_df)

# 결과를 CSV 파일로 저장
output_df.to_csv('./output.csv', index=False)
# Out:
# 저장된 결과:
#       수요지 id 학교 id  할당 학령인구
# 0         C1    F2        0
# 1         C1    F3        0
# 2         C1    F6        0
# 3         C1    F8        0
# 4         C1    F9        0
# ...      ...   ...      ...
# 13368   C311   F46        0
# 13369   C311   F47        0
# 13370   C311   F48        0
# 13371   C311   F49        0
# 13372   C311   F50        0
#
# [13373 rows x 3 columns]

# %%
submission = pd.read_csv("/content/drive/MyDrive/주제1/submission.csv")

for i in range(num_demands):
    demand_id = demand.loc[i, '수요지 id']
    demand_population = demand.loc[i, '초등학령인구']

    for j in range(num_candidates):
        school_id = candidate.loc[j, '학교 id']
        assigned = value(assignments[(i, j)]) == 1

        row_idx = submission.index[
            (submission['수요지 id'] == demand_id) & (submission['학교 id'] == school_id)
        ]

        if len(row_idx) > 0:
            submission.loc[row_idx, '할당 학령인구'] = demand_population if assigned else 0

submission.to_csv("submission.csv", index=False, encoding='cp949')

# %%
accident = pd.read_csv('/content/도로교통공단_교통사고다발지역_20230125.csv', encoding='cp949')
accident
# Out:
#        사고지역관리번호  사고연도  사고유형구분      위치코드   사고다발지역시도시군구  \
# 0       2013060  2012  스쿨존어린이  11110001    서울특별시 종로구1
# 1       2013060  2012  스쿨존어린이  11290001    서울특별시 성북구1
# 2       2013060  2012  스쿨존어린이  11290002    서울특별시 성북구2
# 3       2013060  2012  스쿨존어린이  11290003    서울특별시 성북구3
# 4       2013060  2012  스쿨존어린이  11320001    서울특별시 도봉구1
# ...         ...   ...     ...       ...           ...
# 13358   2022084  2021   보행어린이  45140001     전라북도 익산시1
# 13359   2022084  2021   보행어린이  46110001     전라남도 목포시1
# 13360   2022084  2021   보행어린이  46110002     전라남도 목포시2
# 13361   2022084  2021   보행어린이  47130001     경상북도 경주시1
# 13362   2022084  2021   보행어린이  50110001  제주특별자치도 제주시1
#
#                           사고지역위치명  사고건수  사상자수  사망자수  중상자수  경상자수  부상신고자수  \
# 0          서울특별시 종로구 혜화동(혜화초교 부근)     2     2     0     1     1       0
# 1          서울특별시 성북구 종암동(숭례초교 부근)     2     2     0     0     1       1
# 2       서울특별시 성북구 동소문동7가(정덕초교 부근)     2     2     0     2     0       0
# 3          서울특별시 성북구 석관동(석관초교 부근)     3     3     0     2     1       0
# 4          서울특별시 도봉구 쌍문동(쌍문초교 부근)     2     2     0     0     2       0
# ...                           ...   ...   ...   ...   ...   ...     ...
# 13358       전라북도 익산시 영등동(천일빌라 부근)     3     3     0     0     3       0
# 13359     전라남도 목포시 용해동(목포용해초교 부근)     3     3     0     1     2       0
# 13360     전라남도 목포시 산정동(목포주안교회 부근)     3     3     0     0     3       0
# 13361       경상북도 경주시 용강동(황성초교 부근)     4     4     0     1     3       0
# 13362  제주특별자치도 제주시 연동(제주중앙중학교 부근)     3     3     0     1     2       0
#
#               위도          경도  \
# 0      37.588413  126.999607
# 1      37.595505  127.035733
# 2      37.597571  127.014564
# 3      37.610429  127.059596
# 4      37.648129  127.024430
# ...          ...         ...
# 13358  35.954539  126.973641
# 13359  34.817988  126.397695
# 13360  34.805209  126.374488
# 13361  35.859953  129.224346
# 13362  33.485542  126.498674
#
#                                              사고다발지역폴리곤정보     데이터기준일자
# 0      {type:Polygon,coordinates:[[[127.002009,37.590...  2023-01-25
# 1      {type:Polygon,coordinates:[[[127.0381354,37.59...  2023-01-25
# 2      {type:Polygon,coordinates:[[[127.0169658,37.59...  2023-01-25
# 3      {type:Polygon,coordinates:[[[127.0619982,37.61...  2023-01-25
# 4      {type:Polygon,coordinates:[[[127.0268336,37.65...  2023-01-25
# ...                                                  ...         ...
# 13358  {type:Polygon,coordinates:[[[126.97543771,35.9...  2023-01-25
# 13359  {type:Polygon,coordinates:[[[126.39949123,34.8...  2023-01-25
# 13360  {type:Polygon,coordinates:[[[126.37628414,34.8...  2023-01-25
# 13361  {type:Polygon,coordinates:[[[129.22614311,35.8...  2023-01-25
# 13362  {type:Polygon,coordinates:[[[126.50047028,33.4...  2023-01-25
#
# [13363 rows x 16 columns]

# %%
incheon_accident = accident[accident['사고다발지역시도시군구'].str.contains('인천')]

# %%
incheon_accident1 = incheon_accident[incheon_accident['사고다발지역시도시군구'].str.contains('중구|동구')]


for index, row in incheon_accident1.iterrows():
    location = [row['위도'], row['경도']]
    tooltip = f"사고지역: {row['사고지역위치명']}, 사고건수: {row['사고건수']}건"
    folium.Marker(location=location, icon=folium.Icon(color='purple'), tooltip=tooltip).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34704a3e4b44afe1578334b719480d6b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34704a3e4b44afe1578334b719480d6b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34704a3e4b44afe1578334b719480d6b = L.map(
#                 &quot;map_34704a3e4b44afe1578334b719480d6b&quot;,
#                 {
#                     center: [37.48130973118971, 126.59871058778138],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e323b52f58eaacc609e1aa5c1377e9d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_34704a3e4b44afe1578334b719480d6b);
#
#
#             var marker_2a1b34c8aec9327a344b19ce33f80e57 = L.marker(
#                 [37.4637824, 126.3715048],
#                 {}
#             ).addTo(map_34704a3e4b44afe1578334b719480d6b);
#
#
#             var icon_07698df43fe85d5525fa305dc115fe2c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2a1b34c8aec9327a344b19ce33f80e57.setIcon(icon_07698df43fe85d5525fa305dc115fe2c);
#
#
#             marker_2a1b34c8aec9327a344b19ce33f80e57.bindTooltip(
#                 `&lt;div&gt;
#                      Demand C1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e995af491d3d42cfe7cdba2b3daf8df2 = L.marker(
#                 [37.4957824, 126.4795048],
#                 {}
#             ).addTo(map_34704a3e4b44afe1578334b719480d6b);
#
#
#             var icon_73793f09d102e76f015a9ae97b0bfe36 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e995af491d3d42cfe7cdba2b3daf8df2.setIcon(icon_73793f09d102e76f015a9ae97b0bfe36);
#
#
#             marker_e995af491d3d42cfe7cdba2b3daf8df2.bindTooltip(
#                 `&lt;div&gt;
#                      Demand C2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ddbe51e33fcc0d0c8e036e11d5bbe10d = L.marker(
#                 [37.4997824, 126.4815048],
#                 {}
#             ).addTo(map_34704a3e4b44afe1578334b719480d6b);
#
#
#             var icon_ae30fd3fceafd92122169cbd464fbf64 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ddbe51e33fcc0d0c8e036e11d5bbe10d.setIcon(icon_ae30fd3fceafd92122169cbd464fbf64);
#
#
#             marker_ddbe51e33fcc0d0c8e036e11d5bbe10d.bindTooltip(
#                 `&lt;div&gt;
#                      Demand C3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5e77c88457cc53ddd7436a9e18a6633a = L.marker(
#                 [37.4957824, 126.4825048],
#                 {}
#             ).addTo(map_34704a3e4b44afe1578334b719480d6b);
#
#
#             var icon_f5f37121704e46ee8abf74bf00ceeb45 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5e77c88457cc53ddd7436a9e18a6633a.setIcon(icon_f5f37121704e46ee8abf74bf00ceeb45);
#
#
#             marker_5e77c88457cc53ddd7436a9e18a6633a.bindTooltip(
#                 `&lt;div&gt;
#                      Demand C4
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8a6ee166c658e118b8bd02027e25295e = L.marker(
#                 [37.4977824, 126.4835048],
#                 {}
#             ).addTo(map_34704a3e4b44afe1578334b719480d6b);
#
#
#             var icon_fd4914e2ed3147a4c03e63d9cd93e603 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8a6ee1

# %%
m.save("result_map.html")
